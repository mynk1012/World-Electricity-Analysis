# %%
import pandas as pd


df = pd.read_json(r"C:\Users\Vaibhav\OneDrive\Documents\masai\project\electricity_production_oil_sources\API_EG.ELC.PETR.ZS_DS2_en_csv_v2_4356435.json")
#df1 = pd.read_json(r"C:\Users\Vaibhav\OneDrive\Documents\masai\project\electricity_production_renewable_sources\API_EG.ELC.RNWX.KH_DS2_en_csv_v2_4356007.json")

# %%
df.drop(df.index[0],inplace=True)

# %%
df
# Out:
#                               0             1   \
# 1                   Country Name  Country Code
# 2                          Aruba           ABW
# 3    Africa Eastern and Southern           AFE
# 4                    Afghanistan           AFG
# 5     Africa Western and Central           AFW
# ..                           ...           ...
# 263                       Kosovo           XKX
# 264                  Yemen, Rep.           YEM
# 265                 South Africa           ZAF
# 266                       Zambia           ZMB
# 267                     Zimbabwe           ZWE
#
#                                                     2               3     4   \
# 1                                       Indicator Name  Indicator Code  1960
# 2    Electricity production from oil sources (% of ...  EG.ELC.PETR.ZS
# 3    Electricity production from oil sources (% of ...  EG.ELC.PETR.ZS
# 4    Electricity production from oil sources (% of ...  EG.ELC.PETR.ZS
# ...

# %%
headers = df.iloc[0]
df  = pd.DataFrame(df.values[1:], columns=headers)

# %%
temp3 = df

# %%
temp3
# Out:
# 1                   Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
# 1                                       Indicator Name  Indicator Code 1960  \
# 0    Electricity production from oil sources (% of ...  EG.ELC.PETR.ZS
# 1    Electricity production from oil sources (% of ...  EG.ELC.PETR.ZS
# 2    Electricity production from oil sources (% of ...  EG.ELC.PETR.ZS
# 3    Electricity production from oil sources (% of ...  EG.ELC.PETR.ZS
# ...

# %%
df.dtypes
# Out:
# 1
# Country Name      object
# Country Code      object
# Indicator Name    object
# Indicator Code    object
# 1960              object
#                    ...
# 2018.0            object
# 2019.0            object
# 2020.0            object
# 2021.0            object
#                   object
# Length: 67, dtype: object

# %%
temp3 = df
#temp = df.iloc[:,4:]
temp3.head(3)
# Out:
# 1                 Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
#
# 1                                     Indicator Name     Indicator Code  \
# 0  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 1  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
# 1 1960.0 1961.0 1962.0 1963.0 1964.0 1965.0  ...              2013  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN  ...               100
# 1    NaN    NaN    NaN    NaN    NaN    NaN  ...  18.6635016376268
# 2    NaN    NaN    NaN    NaN    NaN    NaN  ...  60.5661354064941
#
# 1              2014              2015              2016              2017  \
# 0               100               100               100               100
# ...

# %%
lst =list(temp3.columns)
lst1 = []
lst.pop()
# Out:
# ''

# %%
# Out:
# 2021.0

# %%
for i in range(len(lst)):
    if(i<4):
        lst1.append(lst[i])
    else:
        lst1.append(int(lst[i]))

# %%
dic = {}
for i in range(len(lst)):
    if(i>4):
        dic[lst[i]]=lst1[i]

# %%
temp3.rename(columns = dic,inplace=True)

# %%
for i in temp3.columns:
    if(temp3[i].isnull().sum()==266):
        temp3.drop(i,axis=1,inplace=True)

# %%
temp3[2012].value_counts().shape
# Out:
# (159,)

# %%
temp3.to_csv('electricity_production_oil_sources.csv')

# %%
for i in temp3.columns:
    for j in temp3[i]:
        temp3[i]=pd.to_numeric(temp3[i],errors="ignore")

# %%
temp3['Age'].fillna(temp3['Age'].mean(),inplace=True)#inplace :null val =true
data3['Age'].mean()
print(data3.isnull().sum())

# %%
for i in range(temp3.shape[0]):
    df[i][i]=df[][i].replace(",","")
# Out:
# 1
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1990              float64
# 1991              float64
# 1992              float64
# 1993              float64
# 1994              float64
# 1995              float64
# 1996              float64
# 1997              float64
# 1998              float64
# 1999              float64
# 2000              float64
# 2001              float64
# 2002              float64
# 2003              float64
# 2004              float64
# 2005              float64
# 2006              float64
# 2007              float64
# 2008              float64
# 2009              float64
# 2010              float64
# 2011              float64
# 2012              float64
# 2013              float64
# 2014              float64
# 2015              float64
# 2016              float64
# 2017              float64
# 2018              float64
# 2019              float64
# 2020              float64
# ...

# %%
temp3.dtypes
# Out:
# 1
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2018              float64
# 2019              float64
# 2020              float64
# 2021              float64
#                   float64
# Length: 67, dtype: object

# %%
temp3.shape
# Out:
# (266, 36)

# %%
temp3
# Out:
# 1                   Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
# 1                                       Indicator Name  Indicator Code  1960  \
# 0    Electric power transmission and distribution l...  EG.ELC.LOSS.ZS   NaN
# 1    Electric power transmission and distribution l...  EG.ELC.LOSS.ZS   NaN
# 2    Electric power transmission and distribution l...  EG.ELC.LOSS.ZS   NaN
# 3    Electric power transmission and distribution l...  EG.ELC.LOSS.ZS   NaN
# ...

# %%
df2 = pd.read_json(r"C:\Users\Vaibhav\OneDrive\Documents\masai\project\electricity_production_renewable_sources\API_EG.ELC.RNWX.KH_DS2_en_csv_v2_4356007.json")

# %%
df2.head(20)
# Out:
#                              0             1   \
# 0             Last Updated Date    2022-07-20
# 1                  Country Name  Country Code
# 2                         Aruba           ABW
# 3   Africa Eastern and Southern           AFE
# 4                   Afghanistan           AFG
# 5    Africa Western and Central           AFW
# 6                        Angola           AGO
# 7                       Albania           ALB
# 8                       Andorra           AND
# 9                    Arab World           ARB
# 10         United Arab Emirates           ARE
# 11                    Argentina           ARG
# 12                      Armenia           ARM
# 13               American Samoa           ASM
# 14          Antigua and Barbuda           ATG
# 15                    Australia           AUS
# 16                      Austria           AUT
# 17                   Azerbaijan           AZE
# 18                      Burundi           BDI
# ...

# %%
dff = pd.read_json(r"C:\Users\Vaibhav\OneDrive\Documents\masai\project\access_to_elec_rural__world\API_EG.ELC.ACCS.RU.ZS_DS2_en_csv_v2_4364070.json")

# %%
dff
# Out:
# 1                   Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
# 1                                       Indicator Name     Indicator Code  \
# 0    Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 1    Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 2    Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 3    Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# ...

# %%
headers = dff.iloc[0]
dff  = pd.DataFrame(dff.values[1:], columns=headers)

# %%
temp3.to_csv('electricity_production_nuclear_sources.csv')

# %%
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 261   NaN
# 262   NaN
# 263   NaN
# 264   NaN
# 265   NaN
# Name: , Length: 266, dtype: float64

# %%
df1.to_csv('electricity_production_renewable_sources.csv')
